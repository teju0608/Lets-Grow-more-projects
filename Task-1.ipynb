# %% [markdown]
# # Intermediate Level

# %% [markdown]
# ## Exploratory Data Analysis on Terrorism dataset

# %% [markdown]
# As a security/defense analyst, try to find out the hot zone of terrorism.

# %% [markdown]
# In this task, we are going to perform Exploratory data analysis on Terrorism dataset to find out the hot zone of terrorism. Exploratory data analysis means analyzing the given data and finding trends, patterns. In this dataset there are many features including countries, states, regions, gang names, weapon types, target types, years, months, days and many more features.

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load Dataset

# %%
df = pd.read_csv('globalterrorismdb_0718dist.csv', encoding='latin1')

# %% [markdown]
# #### Exploratory data analysis

# %%
# display first 5 rows
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
# display last 5 rows
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
#display shape of dataset
df.shape
# Out:
# (181691, 135)

# %% [markdown]
# Hence there ara 181691 rows and 135 columns in the dataset.

# %%
# display column names
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
# rename columns names.
df = df.rename(columns = {'iyear': 'Year', 'imonth' : 'Month', 'iday' : 'Day', 'country_txt' : 'Country', 'region_txt': 'Region',
                         'provstate' : 'State', 'city' : 'City', 'attacktype1_txt' : 'Attack_Type', 'targtype1_txt': 'Target_Type',
                         'targsubtype1_txt' : 'Target_subtype', 'gname' : 'Gang_name', 'weaptype1_txt':'Weapon_Type'})

# %%
df.head()
# Out:
#         eventid  Year  Month  Day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %% [markdown]
# Now here i am taking only those columns which are usefull for analysis.

# %%
df = df[['Year', 'Month', 'Day', 'Country', 'Region', 'State', 'City', 'Attack_Type', 'Target_Type', 'Target_subtype', 'Gang_name', 'Weapon_Type']]

# %%
df.head()
# Out:
#    Year  Month  Day             Country                       Region    State  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean      NaN
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             City                     Attack_Type                  Target_Type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
# ...

# %%
# display information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  int64
#  1   Month           181691 non-null  int64
#  2   Day             181691 non-null  int64
#  3   Country         181691 non-null  object
#  4   Region          181691 non-null  object
#  5   State           181270 non-null  object
#  6   City            181256 non-null  object
#  7   Attack_Type     181691 non-null  object
#  8   Target_Type     181691 non-null  object
#  9   Target_subtype  171318 non-null  object
#  10  Gang_name       181691 non-null  object
#  11  Weapon_Type     181691 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 16.6+ MB

# %%
# display statistical information about dataset
df.describe()
# Out:
#                 Year          Month            Day
# count  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644
# std        13.259430       3.388303       8.814045
# min      1970.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000
# 50%      2009.000000       6.000000      15.000000
# 75%      2014.000000       9.000000      23.000000
# max      2017.000000      12.000000      31.000000

# %%
# display numerical columns
num_cols = df.describe().columns
num_cols
# Out:
# Index(['Year', 'Month', 'Day'], dtype='object')

# %%
# display categorical columns
cat_cols = df.describe(include = 'O').columns
cat_cols
# Out:
# Index(['Country', 'Region', 'State', 'City', 'Attack_Type', 'Target_Type',
#        'Target_subtype', 'Gang_name', 'Weapon_Type'],
#       dtype='object')

# %% [markdown]
# ##### Missing values

# %%
df.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Country               0
# Region                0
# State               421
# City                435
# Attack_Type           0
# Target_Type           0
# Target_subtype    10373
# Gang_name             0
# Weapon_Type           0
# dtype: int64

# %%
# state column has null values
df['State'].unique()
# Out:
# array([nan, 'Federal', 'Tarlac', ..., 'Carlow', 'Western Lakes',
#        'Vidzeme'], dtype=object)

# %%
# replace nan value with unknown value
df['State'] = df['State'].fillna('Unkwon')

# %%
# city column also has nan values
df['City'].unique()
# Out:
# array(['Santo Domingo', 'Mexico city', 'Unknown', ..., 'Hungrum',
#        'Ceelka Geelow', 'Kubentog'], dtype=object)

# %%
# replace nan values with unknown value
df['City'] = df['City'].fillna('Unknown')

# %%
# Target_subtype column has null value
df['Target_subtype'].unique()
# Out:
# array(['Named Civilian',
#        'Diplomatic Personnel (outside of embassy, consulate)',
#        'Radio Journalist/Staff/Facility', 'Embassy/Consulate',
#        'Police Building (headquarters, station, school)',
#        'Police Security Forces/Officers', 'Electricity',
#        'Military Recruiting Station/Academy',
#        'Government Building/Facility/Office',
#        'Military Barracks/Base/Headquarters/Checkpost',
#        'Aircraft (not at an airport)', 'Retail/Grocery/Bakery', nan,
#        'Military Personnel (soldiers, troops, officers, forces)',
#        'School/University/Educational Building',
#        'Multinational Corporation', 'Party Office/Facility',
#        'House/Apartment/Residence', 'Race/Ethnicity Identified',
#        'Judge/Attorney/Court',
#        'Police Patrol (including vehicles and convoys)',
#        'Place of Worship', 'Vehicles/Transportation',
#        'Bus (excluding tourists)',
#        'Politician or Political Party Movement/Meeting/Rally',
# ...

# %%
df['Target_subtype'] = df['Target_subtype'].fillna('Others')

# %%
df.isnull().sum()
# Out:
# Year              0
# Month             0
# Day               0
# Country           0
# Region            0
# State             0
# City              0
# Attack_Type       0
# Target_Type       0
# Target_subtype    0
# Gang_name         0
# Weapon_Type       0
# dtype: int64

# %% [markdown]
# Remove all null values from the dataset.

# %%
df.shape
# Out:
# (181691, 12)

# %% [markdown]
# Now there are 181691 rows and 12 columns in the updated dataset.

# %%
# Find Total countries in the dataset.
total_countries = df['Country'].nunique()
print('Totla number of countries in the dataset: ', total_countries)
# Out:
# Totla number of countries in the dataset:  205

# %%
# Find total regions in the dataset.
total_regions = df['Region'].nunique()
print("Total number of regions in the dataset : ", total_regions)
# Out:
# Total number of regions in the dataset :  12

# %%
# find total gangs in the dataset.
total_gangs = df['Gang_name'].nunique()
print("Total gangs in the dataset: ", total_gangs)
# Out:
# Total gangs in the dataset:  3537

# %%
# Find top 10 countries in the terrorism.
df['Country'].value_counts().head(10)
# Out:
# Country
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: count, dtype: int64

# %%
# find affected top 10 regions 
df['Region'].value_counts().head(10)
# Out:
# Region
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Name: count, dtype: int64

# %%
# find affected top 10 states of terrorism.
df['State'].value_counts().head(10)
# Out:
# State
# Baghdad               7645
# Northern Ireland      4498
# Unknown               4290
# Balochistan           3710
# Saladin               3411
# Al Anbar              3299
# Nineveh               3241
# Sindh                 3206
# Khyber Pakhtunkhwa    3084
# Diyala                3041
# Name: count, dtype: int64

# %%
# Find affected top 10 cities of terrorism
df['City'].value_counts().head(10)
# Out:
# City
# Unknown         10210
# Baghdad          7589
# Karachi          2652
# Lima             2359
# Mosul            2265
# Belfast          2171
# Santiago         1621
# Mogadishu        1581
# San Salvador     1558
# Istanbul         1048
# Name: count, dtype: int64

# %%
# Find top 10 attack types
df['Attack_Type'].value_counts().head(10)
# Out:
# Attack_Type
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: count, dtype: int64

# %%
# Find top 10 target of attacks
df['Target_Type'].value_counts().head(10)
# Out:
# Target_Type
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Name: count, dtype: int64

# %%
# find top 10 gangs
df['Gang_name'].value_counts().head(10)
# Out:
# Gang_name
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Name: count, dtype: int64

# %% [markdown]
# #### Data Visulization

# %% [markdown]
# Find hot zones using data visulization

# %%
plt.figure(figsize = (10,10))
sns.countplot(y = df.Year)
plt.title('Attacks by year')
plt.show()

# %% [markdown]
# From the above graph, we can see that the more attacks were happened on 2014 and then in 2015.  Here we see that from 1970 onwards, the last 6 years attacks score is more. But from 2014 attacks score is decreasing.

# %%
# attacks by month

plt.figure(figsize = (10,5))
sns.countplot(x = df.Month)
plt.title("Attacks by Month")
plt.show()

# %% [markdown]
# From the above graph we can see that,almost every month had same attacks was happened.

# %%
# attacks by day
plt.figure(figsize = (15,5))
sns.countplot(x = df.Day)

plt.title('Attacks by Day')
plt.show()

# %% [markdown]
# From the above graph we can see that, almost every day had same attacks was happened. At day 31 attacks are low and high during 1st and 15th day.

# %%
# attacks by country

plt.figure(figsize = (10,30))
plt.rcParams.update({'font.size':8});
sns.countplot(y = df.Country)
plt.title('Attacks by Country')
plt.show()

# %% [markdown]
# From the above graph we can see that, Iraq country has the highest number of attacks then Pakistan, then Afganistan, India and then follow it.
# Hence government should follow safety in these countries.

# %%
# attacks by region

plt.figure(figsize = (20,5))
sns.countplot(x = df.Region)

plt.title('Attacks by Region')
plt.show()

# %% [markdown]
# From the above graph we can see that, the attacks happened in firstly Middle East and North Africa and secondly South asia.

# %%
# target type

plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size':12});
plt.xticks(rotation = 90)
sns.countplot(x = df.Target_Type)

plt.title('Attacks based on target')
plt.show()

# %% [markdown]
# The attacks based on target is Private citizens and Property, then miliatry.

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size':12});
plt.xticks(rotation = 90)
sns.countplot(x = df.Attack_Type)

plt.title('Based on attack type')
plt.show()

# %% [markdown]
# From the above graph we can see that, the most attack types are Bombing or Explosion.

# %% [markdown]
# Conclusions:
# - the more attacks were happened on 2014 and then in 2015. Here we see that from 1970 onwards, the last 6 years attacks score is more. But from 2014 attacks score is decreasing.
# - almost every month had same attacks was happened.
# - lmost every day had same attacks was happened.
# -  Iraq country has the highest number of attacks then Pakistan, then Afganistan, India and then follow it. Hence government should follow safety in these countries.
# -   the attacks happened in firstly Middle East and North Africa and secondly South asia.
# -   the most attack types are Bombing or Explosion city.
